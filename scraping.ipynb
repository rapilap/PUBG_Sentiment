# %%
from google_play_scraper import reviews, Sort
import pandas as pd

# %%
package = 'com.tencent.ig'

result, _ = reviews(
    package,
    lang='id',
    country='id',
    sort=Sort.NEWEST,
    count=1000,
)

df = pd.DataFrame(result)

df.to_csv('pubg_review.csv', index=False)

df
# Out:
#                                  reviewId             userName  \
# 0    ae07cb08-fa20-43c7-9257-1bb7ee380a75           Ibra Imami
# 1    6c2be583-bae8-4f1d-a900-7c6ec72a3b69         Tirta Sadewa
# 2    81ef1ce3-b4ca-4cdc-a69a-81828d0d5b32       GALIH Hermawan
# 3    e984cfcc-f85c-4474-8fcf-be5987fe520b            ilham Leo
# 4    f3eaafeb-4d94-41db-be30-d9bf9a0244a5            arif umar
# ..                                    ...                  ...
# 995  41b21ee9-3744-43db-926d-d9b4618f5eda           Dery Acung
# 996  e164da93-b226-4c7e-931f-4a4d0d3cb493    Reza Andria Putra
# 997  502621a3-3651-4971-b628-228396054641  deafitri nofitasari
# 998  69aeda27-15fb-4c84-b96a-672b0bbcfcc0          Redmi Note8
# 999  fd8441c4-c2d8-4988-b954-333baa53f2bb               Marton
#
#                                              userImage  \
# 0    https://play-lh.googleusercontent.com/a/ACg8oc...
# 1    https://play-lh.googleusercontent.com/a-/ALV-U...
# ...
